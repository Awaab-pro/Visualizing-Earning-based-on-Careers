# %% [markdown]
# # Visualizing Earning Based on College Majors

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
recent_grads = pd.read_csv("recent-grads.csv")
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
print(recent_grads.head())
print(recent_grads.tail())
recent_grads.describe()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.shape
# Out:
# (173, 21)

# %%
raw_data_count=len(recent_grads)
print('Number of raw rows:', raw_data_count)
# Out:
# Number of raw rows: 173

# %%
recent_grads.dropna()
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %%
recent_grads
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %%
recent_grads = recent_grads.dropna()
cleaned_data_count = len(recent_grads)
print('Number of clean rows:', cleaned_data_count)
# Out:
# Number of clean rows: 172

# %%
recent_grads.plot(x='Sample_size', y='Employed', kind='scatter', title = 'Employed vs. Sample_size')

# %%
ax = recent_grads.plot(x='Sample_size', y='Employed', kind='scatter')
ax.set_title('Employed vs. Sample_size')

# %%
ax = recent_grads.plot(x='Sample_size', y='Median', kind='scatter')
ax.set_title('Median vs. Sample_size')

# %%
ax = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')
ax.set_title('Unemployment_rate vs. Sample_size')

# %%
ax = recent_grads.plot(x='Full_time', y= 'Median', kind = 'scatter')
ax.set_title('Median vs. Full_time')

# %%
ax = recent_grads.plot(x='ShareWomen', y= 'Unemployment_rate', kind = 'scatter')
ax.set_title('Unemployment_rate vs. ShareWomen')

# %%
ax = recent_grads.plot(x='Men', y= 'Median', kind = 'scatter')
ax.set_title('Medain vs. Men')

# %%
ax = recent_grads.plot(x='Women', y= 'Median', kind = 'scatter')
ax.set_title('Medain vs. Women')

# %%
fig, ax = plt.subplots()
ax.scatter(recent_grads["Women"], recent_grads["Median"])
ax.set_title('Medain vs. Women')

# %%
recent_grads['Sample_size'].plot(kind='hist')

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,3000))

# %%
recent_grads['Employed'].hist(bins=25, range=(0,15000))

# %%
recent_grads['Median'].hist(bins=10, range=(0,80000))

# %%
recent_grads['Full_time'].hist(bins=25, range=(0,50000))

# %%
recent_grads['Unemployment_rate'].hist(bins=8, range=(0,0.5))

# %%
recent_grads['ShareWomen'].hist(bins=11, range=(0,.6))

# %%
recent_grads['Men'].hist(bins=25, range=(0,20000))

# %%
recent_grads['Women'].hist(bins=25, range=(0,40000))

# %% [markdown]
# What percent of majors are predominantly male? Predominantly female?
#
# It seems to me by looking at the (sharewomen) histogram, about 43% of majors are predominantly males, and 57% are female
#
#
# What's the most common median salary range?
#
#
# By looking at the (Median) histogram, The most common median salary range is around 40,000 USD

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f923d0f7c50>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median','Unemployment_rate']], figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f923cf27da0>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Men','Women', 'Median']], figsize=(14,14))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f923cb8b710>,
# ...
#       dtype=object)

# %%
recent_grads[:5]['Women'].plot(kind='bar')

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[163:].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')

# %%
recent_grads[163:].plot.bar(x='Major', y='Unemployment_rate')

# %%
import numpy as np

i = recent_grads.pivot_table(index = 'Major_category', values = ['Men','Women'],aggfunc = np.sum)
i
# Out:
#                                           Men     Women
# Major_category
# Agriculture & Natural Resources       40357.0   35263.0
# Arts                                 134390.0  222740.0
# Biology & Life Science               184919.0  268943.0
# Business                             667852.0  634524.0
# Communications & Journalism          131921.0  260680.0
# Computers & Mathematics              208725.0   90283.0
# Education                            103526.0  455603.0
# Engineering                          408307.0  129276.0
# Health                                75517.0  387713.0
# Humanities & Liberal Arts            272846.0  440622.0
# Industrial Arts & Consumer Services  103781.0  126011.0
# Interdisciplinary                      2817.0    9479.0
# Law & Public Policy                   91129.0   87978.0
# Physical Sciences                     95390.0   90089.0
# Psychology & Social Work              98115.0  382892.0
# ...

# %%
i.plot.bar(x = i.index, y= ['Men','Women'])
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/plotting/_core.py:1716: UserWarning:
#
# Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
recent_grads.plot.hexbin(x='Sample_size', y='Median', gridsize=15)
